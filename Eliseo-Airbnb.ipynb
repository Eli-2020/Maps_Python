# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import plotly.express as px

# %matplotlib inline

# %%
airbnb = pd.read_csv("AB_NYC_2019.csv")
airbnb
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
airbnb.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
airbnb.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
airbnb.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# ...

# %%
airbnb.dtypes
# Out:
# id                                  int64
# name                               object
# host_id                             int64
# host_name                          object
# neighbourhood_group                object
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                               int64
# minimum_nights                      int64
# number_of_reviews                   int64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# dtype: object

# %%
airbnb.shape
# Out:
# (48895, 16)

# %%
airbnb.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
airbnb.fillna({'reviews_per_month':0}, inplace=True)
airbnb.fillna({'name':"NoName"}, inplace=True)
airbnb.fillna({'host_name':"JaneDoe"}, inplace=True)
airbnb.fillna({'last_review':"NotReviewed"}, inplace=True)

# %%
airbnb.isnull().sum()
# Out:
# id                                0
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# last_review                       0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# dtype: int64

# %%
airbnb.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
airbnb['price'].describe()
# Out:
# count    48895.000000
# mean       152.720687
# std        240.154170
# min          0.000000
# 25%         69.000000
# 50%        106.000000
# 75%        175.000000
# max      10000.000000
# Name: price, dtype: float64

# %%
airbnb['host_name'].describe()
# Out:
# count       48874
# unique      11452
# top       Michael
# freq          417
# Name: host_name, dtype: object

# %%
host=airbnb['host_name'].value_counts()
host[host>100]
# Out:
# Michael         417
# David           403
# Sonder (NYC)    327
# John            294
# Alex            279
# Blueground      232
# Sarah           227
# Daniel          226
# Jessica         205
# Maria           204
# Mike            194
# Andrew          190
# Anna            187
# Chris           182
# Laura           182
# Melissa         160
# Emily           157
# Jennifer        154
# James           151
# Rachel          146
# Kara            143
# Amy             142
# Jonathan        142
# Michelle        140
# Brian           140
# Jason           140
# Mark            139
# Adam            139
# Ben             135
# Anthony         134
# Andrea          131
# Eric            131
# Nina            128
# Kevin           127
# Peter           125
# Lauren          124
# Joseph          124
# Nick            123
# Stephanie       121
# Ken             121
# Sam             120
# Lisa            119
# Robert          118
# Elizabeth       114
# Nicole          111
# ...

# %%
host[host>100].sum()
# Out:
# 8904

# %%
airbnb['host_id'].describe()
# Out:
# count    4.889500e+04
# mean     6.762001e+07
# std      7.861097e+07
# min      2.438000e+03
# 25%      7.822033e+06
# 50%      3.079382e+07
# 75%      1.074344e+08
# max      2.743213e+08
# Name: host_id, dtype: float64

# %% [markdown]
# # What can we learn about different hosts and areas?

# %% [markdown]
# This is the graphical sample of the total number of rooms classified by district, then the total number of the type of room by category and the combination of the two graphs.

# %%
plt.figure(figsize=(8,4))
sns.countplot(x = airbnb["neighbourhood_group"], 
              order = airbnb["neighbourhood_group"].value_counts().index)
plt.title('Number of rooms available in each Borough of New York City')
plt.show()

# %%
airbnb['neighbourhood_group'].value_counts()
# Out:
# Manhattan        21661
# Brooklyn         20104
# Queens            5666
# Bronx             1091
# Staten Island      373
# Name: neighbourhood_group, dtype: int64

# %%
plt.figure(figsize = (6,4));
counts = airbnb['room_type'].value_counts();
plt.pie(counts,labels = counts.index,colors=['royalblue','limegreen','orange'],autopct='%1.2f%%');
plt.title('Distribution of data with respect to room type')
# Out:
# Text(0.5, 1.0, 'Distribution of data with respect to room type')

# %% [markdown]
# The combination of the total of the rooms by their types shows that Manhattan has a different dynamic from the other districts because in the others the private room is the majority and in Manhattan it is the entire home/apt.

# %%
plt.figure(figsize=(8,4))
sns.countplot(x = airbnb["neighbourhood_group"], hue =airbnb.room_type,
              order = airbnb["neighbourhood_group"].value_counts().index)
plt.title('Number of rooms Types in each Borough of New York City')
plt.show()

# %% [markdown]
# The graph wants to identify the price categories, then the prices are plotted, however, it shows that the rooms with prices less than 200 are concentrated. However, the graph is not good because of the price outliers of 10,000.

# %%
p =sns.displot(data=airbnb, x="price", kde=True)
p.fig.set_size_inches(8, 4)
plt.title('Distribution prices')
plt.show(p)

# %%
airbnb['price'].describe()
# Out:
# count    48895.000000
# mean       152.720687
# std        240.154170
# min          0.000000
# 25%         69.000000
# 50%        106.000000
# 75%        175.000000
# max      10000.000000
# Name: price, dtype: float64

# %%
airbnb["price"][airbnb["price"]<10000].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# The graph wants to identify the price categories, then the prices are plotted, however, it shows that the rooms with prices less than 2000 are concentrated in rooms with less than 500.

# %%
airbnb["price"][airbnb["price"]<2000].hist()
# Out:
# <AxesSubplot:>

# %%
airbnb["price"][airbnb["price"]<600].hist()
# Out:
# <AxesSubplot:>

# %%
airbnb["price"][airbnb["price"]<300].hist()
# Out:
# <AxesSubplot:>

# %%
airbnb["price"][airbnb["price"]<106].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# It identifies which are the most desirable neighborhoods and which have more rooms available, a minimum limit of 100 rooms is set to be in the ranking. there are 13 neighborhoods that are the most popular.

# %%
Nb=airbnb['neighbourhood'].value_counts()
Nb[Nb>1000]
# Out:
# Williamsburg          3920
# Bedford-Stuyvesant    3714
# Harlem                2658
# Bushwick              2465
# Upper West Side       1971
# Hell's Kitchen        1958
# East Village          1853
# Upper East Side       1798
# Crown Heights         1564
# Midtown               1545
# East Harlem           1117
# Greenpoint            1115
# Chelsea               1113
# Name: neighbourhood, dtype: int64

# %%
Nb[Nb>2000].sum()
# Out:
# 12757

# %%
Nb[Nb>1000].sum()
# Out:
# 26791

# %%
Nb[Nb<=1000].sum()
# Out:
# 22104

# %%
price=airbnb[airbnb['price']>=175]
price
# Out:
#              id                                               name    host_id  \
# 1          2595                              Skylit Midtown Castle       2845
# 5          5099          Large Cozy 1 BR Apartment In Midtown East       7322
# 16         7097                  Perfect for Your Parents + Garden      17571
# 19         7750                  Huge 2 BR Upper East  Cental Park      17985
# 20         7801                   Sweet and Spacious Brooklyn Loft      21207
# ...         ...                                                ...        ...
# 48853  36455917     Sunny&quiet paradise in the WV with open views  274103383
# 48856  36457700  Large 3 bed, 2 bath , garden , bbq , all you need   66993395
# 48872  36476675                                      Nycity-MyHome    8636072
# 48884  36482783        Brooklyn Oasis in the heart of Williamsburg  274307600
# 48886  36483010                    Comfy 1 Bedroom in Midtown East  274311461
#
# ...

# %% [markdown]
# # Which hosts are the busiest and why?

# %% [markdown]
# To identify the busiest hosts, a calculation is made of the number of times the "host_id" is repeated, that gives the largest hosts and it was identified that the largest hosts have more than 100 rooms available.

# %%
host_id=airbnb['host_id'].value_counts()
host_id[host_id>100]
# Out:
# 219517861    327
# 107434423    232
# 30283594     121
# 137358866    103
# Name: host_id, dtype: int64

# %% [markdown]
# The "host id" '219517861' has the highest number of rooms available, in addition to the borought location, also the type of room and the mean of the price.

# %%
airbnb.query("`host_id`== '836168'")["host_id"].value_counts()
# Out:
# 836168    11
# Name: host_id, dtype: int64

# %%
busiest_ng=airbnb.query("`host_id`== '219517861'")["neighbourhood_group"].value_counts()
busiest_ng
# Out:
# Manhattan    327
# Name: neighbourhood_group, dtype: int64

# %%
busiest=airbnb.query("`host_id`== '219517861'")["room_type"].value_counts()
busiest
# Out:
# Entire home/apt    319
# Private room         8
# Name: room_type, dtype: int64

# %%
busiest_p=airbnb.query("`host_id`== '219517861'")["price"].mean()
busiest_p
# Out:
# 253.19571865443424

# %% [markdown]
# Now, it is graphed in which neighbourhoods are located the rooms of the host with more rooms in the city, all located in Manhattan

# %%
busiest_h = airbnb.loc[airbnb["host_id"].isin([('219517861')])]
busiest_h.head(5)
# Out:
#              id                                           name    host_id  \
# 38293  30181691  Sonder | 180 Water | Incredible 2BR + Rooftop  219517861
# 38294  30181945     Sonder | 180 Water | Premier 1BR + Rooftop  219517861
# 38588  30347708    Sonder | 180 Water | Charming 1BR + Rooftop  219517861
# 39769  30937590        Sonder | The Nash | Artsy 1BR + Rooftop  219517861
# 39770  30937591    Sonder | The Nash | Lovely Studio + Rooftop  219517861
#
#           host_name neighbourhood_group       neighbourhood  latitude  \
# 38293  Sonder (NYC)           Manhattan  Financial District  40.70637
# 38294  Sonder (NYC)           Manhattan  Financial District  40.70771
# 38588  Sonder (NYC)           Manhattan  Financial District  40.70743
# 39769  Sonder (NYC)           Manhattan         Murray Hill  40.74792
# 39770  Sonder (NYC)           Manhattan         Murray Hill  40.74771
#
#        longitude        room_type  price  minimum_nights  number_of_reviews  \
# ...

# %%
busiest_n=airbnb.query("`host_id`== '219517861'")["neighbourhood"].value_counts()
busiest_n
# Out:
# Financial District    218
# Murray Hill            50
# Theater District       27
# Hell's Kitchen         15
# Chelsea                 7
# Upper East Side         6
# Midtown                 4
# Name: neighbourhood, dtype: int64

# %%
busiest_nn=airbnb.query("`host_id`== '137358866'")["max_revenues"].sum()
busiest_nn
# Out:
# 892166

# %%
busiest_1=airbnb.query("`host_id`== '219517861'")["max_revenues"].sum()
busiest_1
# Out:
# 24563716

# %%
plt.figure(figsize=(8, 7))
sns.scatterplot(x=busiest_h['latitude'], y=busiest_h['longitude'], hue=busiest_h['neighbourhood'])
plt.title('Distribution of Rooms in Neighbourhood Busiest Host')
# Out:
# Text(0.5, 1.0, 'Distribution of Rooms in Neighbourhood Busiest Host')

# %% [markdown]
# Now, it is graphed in which places are located the rooms of the four hosts with more rooms in the city, located in different Borough (neighbourhood_group)

# %%
busiest_4 = airbnb.loc[airbnb["host_id"].isin(['219517861','107434423','30283594','137358866'])]
busiest_4.head(5)
# Out:
#             id                                              name   host_id  \
# 9740   7491713      NYC Lavish Studio Apartment Steps from SoHo!  30283594
# 10075  7730160  Furnished NYC 1BR apt near Rockefeller Center!!!  30283594
# 10335  7913426    LUX 1-Bedroom NYC Apartment Near Times Square!  30283594
# 10398  7966358                 NYC High End 2BR Midtown West Apt  30283594
# 10490  8045421                        NYC Chelsea Luxury 1BR Apt  30283594
#
#       host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 9740       Kara           Manhattan  Financial District  40.70862  -74.01408
# 10075      Kara           Manhattan    Theater District  40.75967  -73.98573
# 10335      Kara           Manhattan    Theater District  40.75654  -73.98891
# 10398      Kara           Manhattan             Midtown  40.76633  -73.98145
# 10490      Kara           Manhattan             Chelsea  40.74465  -73.99253
#
# ...

# %%
plt.figure(figsize=(8, 7))
sns.scatterplot(x=busiest_4['latitude'], y=busiest_4['longitude'], hue=busiest_4['neighbourhood_group'])
plt.title('Distribution of 4 Busiest Host')
# Out:
# Text(0.5, 1.0, 'Distribution of 4 Busiest Host')

# %%
airbnb.query("(`host_id` == '219517861' | `host_id` == '107434423'| `host_id`== '30283594'| `host_id` == '137358866')")["neighbourhood_group"].value_counts()
# Out:
# Manhattan    696
# Queens        79
# Brooklyn       8
# Name: neighbourhood_group, dtype: int64

# %% [markdown]
# In addition, a column was added with the multiplication of the availability_365 by the price of the room and it was grouped by the host_id to verify if the busiest are those who can make the most money in this business, the answer is yes, the first three of the ranking by total number of places are the same first three in the max_revenues as those who can earn more money.

# %%
airbnb["max_revenues"]=airbnb["price"]*airbnb["availability_365"]
airbnb.dtypes
# Out:
# id                                  int64
# name                               object
# host_id                             int64
# host_name                          object
# neighbourhood_group                object
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                               int64
# minimum_nights                      int64
# number_of_reviews                   int64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# max_revenues                        int64
# dtype: object

# %%
revenues = airbnb.groupby(["host_id"])["max_revenues"].sum()
revenues.sort_values(ascending=False)
# Out:
# host_id
# 219517861    24563716
# 107434423    18021038
# 30283594     10448235
# 205031545     7686699
# 836168        6376000
#                ...
# 24633966            0
# 24634123            0
# 24636847            0
# 24639120            0
# 2438                0
# Name: max_revenues, Length: 37457, dtype: int64

# %% [markdown]
# # Is there any noticeable difference of traffic among different areas and what could be the reason for it?

# %% [markdown]
# Now,The availability in days of the rooms is plotted, the Boroughs are compared and it is seen if they are concentrated and what their limits are which are the quartiles.

# %%
sns.boxplot(data=airbnb,x='neighbourhood_group',y='availability_365')
plt.gcf()
plt.title('Number of days available in each Borough of New York City')
plt.figure(figsize=(10,10))

# %% [markdown]
# The graph reflects the great difference between Manhattan and Staten island, the total number of rooms available, mean, median, 75% and this related to the days available. in general the rooms have fewer days available in Manhattan, compared to the other boroughts.

# %%
airbnb.query("`neighbourhood_group`== 'Staten Island'")['availability_365'].describe()
# Out:
# count    373.000000
# mean     199.678284
# std      131.852000
# min        0.000000
# 25%       78.000000
# 50%      219.000000
# 75%      333.000000
# max      365.000000
# Name: availability_365, dtype: float64

# %%
airbnb.query("`neighbourhood_group`== 'Manhattan'")['availability_365'].describe()
# Out:
# count    21661.000000
# mean       111.979410
# std        132.677836
# min          0.000000
# 25%          0.000000
# 50%         36.000000
# 75%        230.000000
# max        365.000000
# Name: availability_365, dtype: float64

# %% [markdown]
# the vast majority of rooms are available less than 50 days

# %%
airbnb["availability_365"].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Latitude + Longitude

# %% [markdown]
# It is the location of all the available rooms that end up forming the five boroughts in NY, it is incredible that the presence is throughout the city and the water areas can be identified.

# %%
plt.figure(figsize=(8, 8))
sns.scatterplot(x=airbnb['longitude'], y=airbnb['latitude'], hue=airbnb['neighbourhood_group'])
plt.title('Distribution of Rooms in New York City')
# Out:
# Text(0.5, 1.0, 'Distribution of Rooms in New York City')

# %% [markdown]
# It is the location of all the rooms available by their types of forming the city of NY, you can see that the two predominant types of rooms are throughout the city regardless of the boroughts, the shared rooms are in only some areas of the city.

# %%
plt.figure(figsize=(6, 6))
sns.scatterplot(x=airbnb['longitude'], y=airbnb['latitude'], hue=airbnb['room_type'])
plt.title('Distribution of Room Type in NY')
# Out:
# Text(0.5, 1.0, 'Distribution of Room Type in NY')

# %%
price=airbnb['price'].value_counts()
price[price>100]
# Out:
# 100    2051
# 150    2047
# 50     1534
# 60     1458
# 200    1401
#        ...
# 63      108
# 67      107
# 239     106
# 36      103
# 46      102
# Name: price, Length: 92, dtype: int64

# %%
a=airbnb["price"][airbnb["price"]<10000].mean()
a
# Out:
# 152.11646077067823

# %% [markdown]
# Finally, two more columns were added, the first one to group the prices into categories based on the first price charts, this one is called price_label; their ranges are made with the pd.cut function where the numbers are given by creating five categories and replacing the previous value in the column with the corresponding category. In the second new column, something similar is done but with the idea of assigning categories with names so that you can make visible which are the areas that have the categories with the highest prices that are: 4 and 5 by density color.

# %%
airbnb["price_category"]=airbnb["price"]
airbnb.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365', 'price_label', 'price_category'],
#       dtype='object')

# %%
airbnb.dtypes
# Out:
# id                                   int64
# name                                object
# host_id                              int64
# host_name                           object
# neighbourhood_group                 object
# neighbourhood                       object
# latitude                           float64
# longitude                          float64
# room_type                           object
# price                                int64
# minimum_nights                       int64
# number_of_reviews                    int64
# last_review                         object
# reviews_per_month                  float64
# calculated_host_listings_count       int64
# availability_365                     int64
# price_label                       category
# price_category                     float64
# dtype: object

# %%
airbnb["price_category"] = airbnb["price_category"].astype('float64')

# %%
airbnb.dtypes
# Out:
# id                                   int64
# name                                object
# host_id                              int64
# host_name                           object
# neighbourhood_group                 object
# neighbourhood                       object
# latitude                           float64
# longitude                          float64
# room_type                           object
# price                                int64
# minimum_nights                       int64
# number_of_reviews                    int64
# last_review                         object
# reviews_per_month                  float64
# calculated_host_listings_count       int64
# availability_365                     int64
# price_label                       category
# price_category                     float64
# dtype: object

# %%
bins=[0,100,175,250,500,10000]
names=["1","2","3","4","5"]
airbnb["price_category"]=pd.cut(airbnb["price_category"],bins,labels=names)

# %%
plt.figure(figsize=(8, 7))
sns.scatterplot(x=airbnb['longitude'], y=airbnb['latitude'], hue=airbnb['price_category'], size=airbnb['price_category'])
plt.title('Category of Prices in NY by color density')
# Out:
# Text(0.5, 1.0, 'Category of Prices in NY by color density')

# %%
airbnb["price_label"]=airbnb["price"]
airbnb.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365', 'price_label'],
#       dtype='object')

# %%
bins=[0,100,175,250,500,10000]
names=["Low","Medium","High","Businness","Monarchy"]
airbnb["price_label"]=pd.cut(airbnb["price_label"],bins,labels=names)

# %%
plt.figure(figsize=(8, 7))
sns.scatterplot(x=airbnb['longitude'], y=airbnb['latitude'], hue=airbnb['price_label'])
plt.title('Category of Prices in NY')
# Out:
# Text(0.5, 1.0, 'Category of Prices in NY')

# %%
airbnb["price_label"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-8681fd5021df> in <module>
# ----> 1 airbnb["price_label"].value_counts()
#
# NameError: name 'airbnb' is not defined
